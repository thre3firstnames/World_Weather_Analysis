# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key & Create the URL Variable
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Create a list of latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# find the City C
len(cities)
# Out:
# 751

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | saskylakh
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | marshall
# Processing Record 6 of Set 1 | san miguel
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | sisimiut
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | omsukchan
# Processing Record 12 of Set 1 | port lincoln
# Processing Record 13 of Set 1 | te anau
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | hamilton
# Processing Record 16 of Set 1 | tarakan
# Processing Record 17 of Set 1 | pilna
# Processing Record 18 of Set 1 | kaeo
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | saint pete beach
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | massaguet
# Processing Record 29 of Set 1 | manokwari
# Processing Record 30 of Set 1 | saint-pierre
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | malpe
# Processing Record 33 of Set 1 | upington
# Processing Record 34 of Set 1 | havelock
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | yerbogachen
# Processing Record 37 of Set 1 | narsaq
# Processing Record 38 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 1 | tessalit
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | salalah
# Processing Record 42 of Set 1 | longyearbyen
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | quatis
# Processing Record 46 of Set 1 | port blair
# Processing Record 47 of Set 1 | fairbanks
# Processing Record 48 of Set 1 | marsh harbour
# Processing Record 49 of Set 1 | amahai
# Processing Record 50 of Set 1 | namibe
# Processing Record 1 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 2 | faanui
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | sinjar
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | codrington
# Processing Record 10 of Set 2 | zalantun
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | esperance
# Processing Record 13 of Set 2 | victoria
# Processing Record 14 of Set 2 | lugovskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | meiktila
# Processing Record 16 of Set 2 | hami
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | olafsvik
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | kargasok
# Processing Record 22 of Set 2 | mount isa
# Processing Record 23 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 2 | mahibadhoo
# Processing Record 25 of Set 2 | dingle
# Processing Record 26 of Set 2 | lamar
# Processing Record 27 of Set 2 | charters towers
# Processing Record 28 of Set 2 | matagami
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | aden
# Processing Record 31 of Set 2 | ambulu
# Processing Record 32 of Set 2 | abu dhabi
# Processing Record 33 of Set 2 | waterfoot
# Processing Record 34 of Set 2 | zeerust
# Processing Record 35 of Set 2 | cam ranh
# Processing Record 36 of Set 2 | bloomingdale
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | vicuna
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | cururupu
# Processing Record 42 of Set 2 | kirakira
# Processing Record 43 of Set 2 | shimoda
# Processing Record 44 of Set 2 | saskatoon
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | coahuayana
# Processing Record 47 of Set 2 | maningrida
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | sangar
# Processing Record 50 of Set 2 | tasiilaq
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | bor
# Processing Record 3 of Set 3 | kahului
# Processing Record 4 of Set 3 | linjiang
# Processing Record 5 of Set 3 | san angelo
# Processing Record 6 of Set 3 | ketchikan
# Processing Record 7 of Set 3 | fort frances
# Processing Record 8 of Set 3 | arrecife
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | angoram
# Processing Record 11 of Set 3 | faya
# Processing Record 12 of Set 3 | broken hill
# Processing Record 13 of Set 3 | domanivka
# Processing Record 14 of Set 3 | maarianhamina
# Processing Record 15 of Set 3 | ferrol
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | isangel
# Processing Record 18 of Set 3 | launceston
# Processing Record 19 of Set 3 | nishihara
# Processing Record 20 of Set 3 | oktyabrskoye
# Processing Record 21 of Set 3 | port hardy
# Processing Record 22 of Set 3 | alofi
# Processing Record 23 of Set 3 | sanski most
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | yantal
# Processing Record 26 of Set 3 | erzin
# Processing Record 27 of Set 3 | mayor pablo lagerenza
# Processing Record 28 of Set 3 | mirina
# City not found. Skipping...
# Processing Record 29 of Set 3 | hualmay
# Processing Record 30 of Set 3 | soltsy
# Processing Record 31 of Set 3 | tunghsiao
# City not found. Skipping...
# Processing Record 32 of Set 3 | pyaozerskiy
# Processing Record 33 of Set 3 | pemangkat
# Processing Record 34 of Set 3 | cherskiy
# Processing Record 35 of Set 3 | saint-georges
# Processing Record 36 of Set 3 | bayir
# Processing Record 37 of Set 3 | turukhansk
# Processing Record 38 of Set 3 | hobart
# Processing Record 39 of Set 3 | mogadishu
# Processing Record 40 of Set 3 | texarkana
# Processing Record 41 of Set 3 | ouadda
# Processing Record 42 of Set 3 | asau
# Processing Record 43 of Set 3 | talnakh
# Processing Record 44 of Set 3 | vao
# Processing Record 45 of Set 3 | broome
# Processing Record 46 of Set 3 | mariental
# Processing Record 47 of Set 3 | pangnirtung
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 3 | kailua
# Processing Record 1 of Set 4 | svetlogorsk
# Processing Record 2 of Set 4 | iqaluit
# Processing Record 3 of Set 4 | la ronge
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | ulaanbaatar
# Processing Record 6 of Set 4 | shush
# Processing Record 7 of Set 4 | bensonville
# Processing Record 8 of Set 4 | bengkulu
# Processing Record 9 of Set 4 | la rioja
# Processing Record 10 of Set 4 | touros
# Processing Record 11 of Set 4 | vilyuysk
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | sorong
# Processing Record 14 of Set 4 | novyy urengoy
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 4 | norman wells
# Processing Record 17 of Set 4 | necochea
# Processing Record 18 of Set 4 | omutinskoye
# City not found. Skipping...
# Processing Record 19 of Set 4 | butaritari
# Processing Record 20 of Set 4 | bilibino
# Processing Record 21 of Set 4 | itaituba
# Processing Record 22 of Set 4 | northam
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | wladyslawowo
# Processing Record 25 of Set 4 | ostrovnoy
# Processing Record 26 of Set 4 | osorno
# Processing Record 27 of Set 4 | ambilobe
# Processing Record 28 of Set 4 | hithadhoo
# Processing Record 29 of Set 4 | damietta
# Processing Record 30 of Set 4 | haines junction
# Processing Record 31 of Set 4 | nouadhibou
# Processing Record 32 of Set 4 | bilma
# Processing Record 33 of Set 4 | rio grande
# Processing Record 34 of Set 4 | filingue
# Processing Record 35 of Set 4 | kiunga
# Processing Record 36 of Set 4 | aneho
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | tommot
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 4 | kaitangata
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | clyde river
# Processing Record 44 of Set 4 | tateyama
# Processing Record 45 of Set 4 | dandong
# Processing Record 46 of Set 4 | moerai
# Processing Record 47 of Set 4 | la palma
# Processing Record 48 of Set 4 | east london
# Processing Record 49 of Set 4 | thompson
# Processing Record 50 of Set 4 | banda aceh
# Processing Record 1 of Set 5 | samtredia
# Processing Record 2 of Set 5 | ilhabela
# Processing Record 3 of Set 5 | angra
# City not found. Skipping...
# Processing Record 4 of Set 5 | laguna
# Processing Record 5 of Set 5 | pahrump
# Processing Record 6 of Set 5 | lebu
# Processing Record 7 of Set 5 | beaverlodge
# Processing Record 8 of Set 5 | miri
# Processing Record 9 of Set 5 | doha
# Processing Record 10 of Set 5 | kamsack
# Processing Record 11 of Set 5 | high level
# Processing Record 12 of Set 5 | kungurtug
# Processing Record 13 of Set 5 | kendrapara
# Processing Record 14 of Set 5 | kodiak
# Processing Record 15 of Set 5 | hermanus
# Processing Record 16 of Set 5 | oyotun
# Processing Record 17 of Set 5 | feijo
# Processing Record 18 of Set 5 | lata
# Processing Record 19 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | sao borja
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | chokurdakh
# Processing Record 24 of Set 5 | nanortalik
# Processing Record 25 of Set 5 | strezhevoy
# Processing Record 26 of Set 5 | llata
# Processing Record 27 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 5 | leningradskiy
# Processing Record 29 of Set 5 | buraydah
# Processing Record 30 of Set 5 | stolin
# Processing Record 31 of Set 5 | makakilo city
# Processing Record 32 of Set 5 | mitsamiouli
# Processing Record 33 of Set 5 | innisfail
# Processing Record 34 of Set 5 | alice springs
# Processing Record 35 of Set 5 | san cristobal
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | esmeraldas
# Processing Record 38 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 5 | bonavista
# Processing Record 40 of Set 5 | ojinaga
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | rabo de peixe
# Processing Record 43 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 5 | sur
# Processing Record 45 of Set 5 | golyshmanovo
# Processing Record 46 of Set 5 | kartaly
# Processing Record 47 of Set 5 | riyadh
# Processing Record 48 of Set 5 | birjand
# Processing Record 49 of Set 5 | zhigansk
# Processing Record 50 of Set 5 | batagay
# Processing Record 1 of Set 6 | san quintin
# Processing Record 2 of Set 6 | atuona
# Processing Record 3 of Set 6 | marsa matruh
# Processing Record 4 of Set 6 | torbay
# Processing Record 5 of Set 6 | baraboo
# Processing Record 6 of Set 6 | shingu
# Processing Record 7 of Set 6 | oranjemund
# Processing Record 8 of Set 6 | san patricio
# Processing Record 9 of Set 6 | puerto del rosario
# Processing Record 10 of Set 6 | mercedes
# Processing Record 11 of Set 6 | henties bay
# Processing Record 12 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 6 | plouzane
# Processing Record 14 of Set 6 | belaya gora
# Processing Record 15 of Set 6 | bairiki
# Processing Record 16 of Set 6 | harper
# Processing Record 17 of Set 6 | dunedin
# Processing Record 18 of Set 6 | san pedro
# Processing Record 19 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 6 | alice town
# Processing Record 21 of Set 6 | solikamsk
# Processing Record 22 of Set 6 | chunskiy
# Processing Record 23 of Set 6 | lavrentiya
# Processing Record 24 of Set 6 | young
# Processing Record 25 of Set 6 | vojka
# Processing Record 26 of Set 6 | yar-sale
# Processing Record 27 of Set 6 | ribeira grande
# Processing Record 28 of Set 6 | cervo
# Processing Record 29 of Set 6 | lukovetskiy
# Processing Record 30 of Set 6 | susangerd
# Processing Record 31 of Set 6 | yumen
# Processing Record 32 of Set 6 | teya
# Processing Record 33 of Set 6 | aswan
# Processing Record 34 of Set 6 | naryan-mar
# Processing Record 35 of Set 6 | cochrane
# Processing Record 36 of Set 6 | hovd
# Processing Record 37 of Set 6 | los llanos de aridane
# Processing Record 38 of Set 6 | plyussa
# Processing Record 39 of Set 6 | korla
# Processing Record 40 of Set 6 | paamiut
# Processing Record 41 of Set 6 | portland
# Processing Record 42 of Set 6 | solaro
# Processing Record 43 of Set 6 | mitu
# Processing Record 44 of Set 6 | chicama
# Processing Record 45 of Set 6 | minot
# Processing Record 46 of Set 6 | christchurch
# Processing Record 47 of Set 6 | vanimo
# Processing Record 48 of Set 6 | kenai
# Processing Record 49 of Set 6 | qixia
# Processing Record 50 of Set 6 | mikhaylovka
# Processing Record 1 of Set 7 | vestmannaeyjar
# Processing Record 2 of Set 7 | udachnyy
# Processing Record 3 of Set 7 | cockburn town
# Processing Record 4 of Set 7 | bambous virieux
# Processing Record 5 of Set 7 | nalut
# Processing Record 6 of Set 7 | grenaa
# Processing Record 7 of Set 7 | amga
# Processing Record 8 of Set 7 | kovdor
# Processing Record 9 of Set 7 | cabo san lucas
# Processing Record 10 of Set 7 | anadyr
# Processing Record 11 of Set 7 | springdale
# Processing Record 12 of Set 7 | santa maria
# Processing Record 13 of Set 7 | dhidhdhoo
# Processing Record 14 of Set 7 | otane
# Processing Record 15 of Set 7 | huanren
# Processing Record 16 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 17 of Set 7 | dukat
# Processing Record 18 of Set 7 | allonnes
# Processing Record 19 of Set 7 | guerrero negro
# Processing Record 20 of Set 7 | malanje
# Processing Record 21 of Set 7 | mukhen
# Processing Record 22 of Set 7 | kichera
# Processing Record 23 of Set 7 | college
# Processing Record 24 of Set 7 | port keats
# Processing Record 25 of Set 7 | beringovskiy
# Processing Record 26 of Set 7 | biloela
# Processing Record 27 of Set 7 | kavieng
# Processing Record 28 of Set 7 | deputatskiy
# Processing Record 29 of Set 7 | pangody
# Processing Record 30 of Set 7 | bandarbeyla
# Processing Record 31 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 7 | halifax
# Processing Record 33 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 34 of Set 7 | mount gambier
# Processing Record 35 of Set 7 | barcelona
# Processing Record 36 of Set 7 | bjornevatn
# Processing Record 37 of Set 7 | hofn
# Processing Record 38 of Set 7 | aklavik
# Processing Record 39 of Set 7 | sola
# Processing Record 40 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 7 | porto novo
# Processing Record 42 of Set 7 | palmer
# Processing Record 43 of Set 7 | middelburg
# Processing Record 44 of Set 7 | savannah bight
# Processing Record 45 of Set 7 | el alto
# Processing Record 46 of Set 7 | batagay-alyta
# Processing Record 47 of Set 7 | padang
# Processing Record 48 of Set 7 | roebourne
# Processing Record 49 of Set 7 | manbij
# Processing Record 50 of Set 7 | stepnyak
# Processing Record 1 of Set 8 | russell
# Processing Record 2 of Set 8 | tahoua
# Processing Record 3 of Set 8 | kruisfontein
# Processing Record 4 of Set 8 | izhma
# Processing Record 5 of Set 8 | constitucion
# Processing Record 6 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 8 | suzu
# City not found. Skipping...
# Processing Record 8 of Set 8 | kununurra
# Processing Record 9 of Set 8 | yarkovo
# Processing Record 10 of Set 8 | san vicente
# Processing Record 11 of Set 8 | port elizabeth
# Processing Record 12 of Set 8 | yenagoa
# Processing Record 13 of Set 8 | kiruna
# Processing Record 14 of Set 8 | salekhard
# Processing Record 15 of Set 8 | skibbereen
# Processing Record 16 of Set 8 | paita
# Processing Record 17 of Set 8 | miles city
# Processing Record 18 of Set 8 | margate
# Processing Record 19 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 8 | kota kinabalu
# Processing Record 21 of Set 8 | kloulklubed
# Processing Record 22 of Set 8 | krasnorechenskiy
# Processing Record 23 of Set 8 | orotukan
# Processing Record 24 of Set 8 | biak
# Processing Record 25 of Set 8 | luba
# Processing Record 26 of Set 8 | vytegra
# Processing Record 27 of Set 8 | kabin buri
# Processing Record 28 of Set 8 | bathsheba
# Processing Record 29 of Set 8 | belyy yar
# Processing Record 30 of Set 8 | khromtau
# Processing Record 31 of Set 8 | sambava
# Processing Record 32 of Set 8 | alyangula
# Processing Record 33 of Set 8 | buala
# Processing Record 34 of Set 8 | vredendal
# Processing Record 35 of Set 8 | sorland
# Processing Record 36 of Set 8 | chickasha
# Processing Record 37 of Set 8 | merauke
# Processing Record 38 of Set 8 | severo-kurilsk
# Processing Record 39 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 40 of Set 8 | bougouni
# Processing Record 41 of Set 8 | pimentel
# Processing Record 42 of Set 8 | senanga
# Processing Record 43 of Set 8 | yulara
# Processing Record 44 of Set 8 | kalengwa
# Processing Record 45 of Set 8 | marawi
# Processing Record 46 of Set 8 | shenjiamen
# Processing Record 47 of Set 8 | athens
# Processing Record 48 of Set 8 | altamirano
# Processing Record 49 of Set 8 | cayenne
# Processing Record 50 of Set 8 | owerri
# Processing Record 1 of Set 9 | seoul
# Processing Record 2 of Set 9 | nakamura
# Processing Record 3 of Set 9 | sandakan
# Processing Record 4 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 5 of Set 9 | sao joao da barra
# Processing Record 6 of Set 9 | wanning
# Processing Record 7 of Set 9 | fomboni
# Processing Record 8 of Set 9 | rawson
# Processing Record 9 of Set 9 | okha
# Processing Record 10 of Set 9 | kudahuvadhoo
# Processing Record 11 of Set 9 | airai
# Processing Record 12 of Set 9 | rio pardo
# Processing Record 13 of Set 9 | zholymbet
# Processing Record 14 of Set 9 | los cedrales
# Processing Record 15 of Set 9 | lewistown
# Processing Record 16 of Set 9 | la paz
# Processing Record 17 of Set 9 | vyshneve
# Processing Record 18 of Set 9 | olot
# Processing Record 19 of Set 9 | mahebourg
# Processing Record 20 of Set 9 | hermon
# Processing Record 21 of Set 9 | pilar do sul
# Processing Record 22 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 9 | pangai
# Processing Record 24 of Set 9 | tura
# Processing Record 25 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 9 | odweyne
# Processing Record 27 of Set 9 | ust-tsilma
# Processing Record 28 of Set 9 | olkhovatka
# Processing Record 29 of Set 9 | eenhana
# Processing Record 30 of Set 9 | pacific grove
# Processing Record 31 of Set 9 | katsuura
# Processing Record 32 of Set 9 | atar
# Processing Record 33 of Set 9 | vila franca do campo
# Processing Record 34 of Set 9 | buena vista
# Processing Record 35 of Set 9 | kawalu
# Processing Record 36 of Set 9 | meulaboh
# Processing Record 37 of Set 9 | burnie
# Processing Record 38 of Set 9 | nouakchott
# Processing Record 39 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 40 of Set 9 | villazon
# Processing Record 41 of Set 9 | yomou
# Processing Record 42 of Set 9 | bingerville
# Processing Record 43 of Set 9 | athabasca
# Processing Record 44 of Set 9 | basoko
# Processing Record 45 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 46 of Set 9 | voyvozh
# Processing Record 47 of Set 9 | mandal
# Processing Record 48 of Set 9 | mayumba
# Processing Record 49 of Set 9 | xining
# Processing Record 50 of Set 9 | talara
# Processing Record 1 of Set 10 | port hedland
# Processing Record 2 of Set 10 | adrar
# Processing Record 3 of Set 10 | lagoa
# Processing Record 4 of Set 10 | svalyava
# Processing Record 5 of Set 10 | baruun-urt
# Processing Record 6 of Set 10 | storforshei
# Processing Record 7 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 8 of Set 10 | juneau
# Processing Record 9 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 10 | zlitan
# Processing Record 11 of Set 10 | coulihaut
# City not found. Skipping...
# Processing Record 12 of Set 10 | murovani kurylivtsi
# Processing Record 13 of Set 10 | vila velha
# Processing Record 14 of Set 10 | kouango
# Processing Record 15 of Set 10 | gimbi
# Processing Record 16 of Set 10 | usinsk
# Processing Record 17 of Set 10 | canon city
# Processing Record 18 of Set 10 | port macquarie
# Processing Record 19 of Set 10 | oriximina
# Processing Record 20 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 10 | nova era
# Processing Record 22 of Set 10 | burgeo
# Processing Record 23 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 10 | husavik
# Processing Record 25 of Set 10 | bocana
# Processing Record 26 of Set 10 | ostersund
# Processing Record 27 of Set 10 | aksha
# Processing Record 28 of Set 10 | dolores
# Processing Record 29 of Set 10 | senador jose porfirio
# Processing Record 30 of Set 10 | katherine
# Processing Record 31 of Set 10 | uyuni
# Processing Record 32 of Set 10 | vanavara
# Processing Record 33 of Set 10 | tunduma
# Processing Record 34 of Set 10 | areka
# Processing Record 35 of Set 10 | san bartolome jocotenango
# Processing Record 36 of Set 10 | nyurba
# Processing Record 37 of Set 10 | samoylovka
# Processing Record 38 of Set 10 | westport
# Processing Record 39 of Set 10 | rio bravo
# Processing Record 40 of Set 10 | villa maria
# Processing Record 41 of Set 10 | klaksvik
# Processing Record 42 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 43 of Set 10 | hasaki
# Processing Record 44 of Set 10 | talakan
# Processing Record 45 of Set 10 | rawah
# Processing Record 46 of Set 10 | yaritagua
# Processing Record 47 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 10 | nuristan
# Processing Record 49 of Set 10 | emba
# Processing Record 50 of Set 10 | krasnoye
# Processing Record 1 of Set 11 | pelym
# Processing Record 2 of Set 11 | iskateley
# Processing Record 3 of Set 11 | cranbrook
# Processing Record 4 of Set 11 | seit
# City not found. Skipping...
# Processing Record 5 of Set 11 | wagrowiec
# Processing Record 6 of Set 11 | rudsar
# Processing Record 7 of Set 11 | loutra
# Processing Record 8 of Set 11 | anta
# Processing Record 9 of Set 11 | cabedelo
# Processing Record 10 of Set 11 | omagh
# Processing Record 11 of Set 11 | batemans bay
# Processing Record 12 of Set 11 | kuusamo
# Processing Record 13 of Set 11 | evensk
# Processing Record 14 of Set 11 | lichuan
# Processing Record 15 of Set 11 | cape coast
# Processing Record 16 of Set 11 | leshukonskoye
# Processing Record 17 of Set 11 | puerto maldonado
# Processing Record 18 of Set 11 | kyren
# Processing Record 19 of Set 11 | the pas
# Processing Record 20 of Set 11 | morondava
# Processing Record 21 of Set 11 | breyten
# Processing Record 22 of Set 11 | mecca
# Processing Record 23 of Set 11 | inhambane
# Processing Record 24 of Set 11 | chapais
# Processing Record 25 of Set 11 | solnechnyy
# Processing Record 26 of Set 11 | boromo
# Processing Record 27 of Set 11 | singaraja
# Processing Record 28 of Set 11 | bloomfield
# Processing Record 29 of Set 11 | kautokeino
# Processing Record 30 of Set 11 | gat
# Processing Record 31 of Set 11 | mersing
# Processing Record 32 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 11 | santa rosa
# Processing Record 34 of Set 11 | ucluelet
# Processing Record 35 of Set 11 | miyoshi
# Processing Record 36 of Set 11 | bow island
# Processing Record 37 of Set 11 | mujiayingzi
# Processing Record 38 of Set 11 | saint-augustin
# Processing Record 39 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 11 | mukono
# Processing Record 41 of Set 11 | millau
# Processing Record 42 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 43 of Set 11 | puerto baquerizo moreno
# Processing Record 44 of Set 11 | acapulco
# Processing Record 45 of Set 11 | gbadolite
# Processing Record 46 of Set 11 | la fria
# Processing Record 47 of Set 11 | mikhaylov
# Processing Record 48 of Set 11 | almeirim
# Processing Record 49 of Set 11 | chokwe
# Processing Record 50 of Set 11 | sabha
# Processing Record 1 of Set 12 | zemio
# Processing Record 2 of Set 12 | develi
# Processing Record 3 of Set 12 | eydhafushi
# Processing Record 4 of Set 12 | mago
# Processing Record 5 of Set 12 | nantucket
# Processing Record 6 of Set 12 | springbok
# Processing Record 7 of Set 12 | lar
# Processing Record 8 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 12 | ilulissat
# Processing Record 10 of Set 12 | nong chik
# Processing Record 11 of Set 12 | shaowu
# Processing Record 12 of Set 12 | phonhong
# Processing Record 13 of Set 12 | sao jose da coroa grande
# Processing Record 14 of Set 12 | maragogi
# Processing Record 15 of Set 12 | san policarpo
# Processing Record 16 of Set 12 | taoudenni
# Processing Record 17 of Set 12 | chumikan
# Processing Record 18 of Set 12 | smirnykh
# Processing Record 19 of Set 12 | yakeshi
# Processing Record 20 of Set 12 | senno
# Processing Record 21 of Set 12 | angicos
# Processing Record 22 of Set 12 | san rafael
# Processing Record 23 of Set 12 | nguruka
# Processing Record 24 of Set 12 | urubicha
# Processing Record 25 of Set 12 | avera
# Processing Record 26 of Set 12 | ogdensburg
# Processing Record 27 of Set 12 | bang saphan
# Processing Record 28 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 12 | micheweni
# Processing Record 30 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 12 | pacifica
# Processing Record 32 of Set 12 | kavaratti
# Processing Record 33 of Set 12 | klyuchi
# Processing Record 34 of Set 12 | misratah
# Processing Record 35 of Set 12 | flinders
# Processing Record 36 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 12 | ust-nera
# Processing Record 38 of Set 12 | bull savanna
# Processing Record 39 of Set 12 | konin
# Processing Record 40 of Set 12 | charleston
# Processing Record 41 of Set 12 | antofagasta
# Processing Record 42 of Set 12 | santiago del estero
# Processing Record 43 of Set 12 | natal
# Processing Record 44 of Set 12 | naze
# Processing Record 45 of Set 12 | nova vicosa
# Processing Record 46 of Set 12 | fallon
# Processing Record 47 of Set 12 | kimbe
# Processing Record 48 of Set 12 | manggar
# Processing Record 49 of Set 12 | cascais
# Processing Record 50 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 13 | mossendjo
# Processing Record 2 of Set 13 | homer
# Processing Record 3 of Set 13 | harjavalta
# Processing Record 4 of Set 13 | abha
# Processing Record 5 of Set 13 | rocha
# Processing Record 6 of Set 13 | cooma
# Processing Record 7 of Set 13 | seymchan
# Processing Record 8 of Set 13 | krasnyy chikoy
# Processing Record 9 of Set 13 | thunder bay
# Processing Record 10 of Set 13 | narvik
# Processing Record 11 of Set 13 | igarka
# Processing Record 12 of Set 13 | dullewala
# Processing Record 13 of Set 13 | algiers
# Processing Record 14 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 13 | kingaroy
# Processing Record 16 of Set 13 | aksu
# Processing Record 17 of Set 13 | opunake
# Processing Record 18 of Set 13 | phan thiet
# Processing Record 19 of Set 13 | quatre cocos
# Processing Record 20 of Set 13 | teguise
# Processing Record 21 of Set 13 | yako
# Processing Record 22 of Set 13 | ibadan
# Processing Record 23 of Set 13 | bourges
# Processing Record 24 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 13 | zhanakorgan
# Processing Record 26 of Set 13 | khorramabad
# Processing Record 27 of Set 13 | takab
# Processing Record 28 of Set 13 | pingliang
# Processing Record 29 of Set 13 | lagos
# Processing Record 30 of Set 13 | chanute
# Processing Record 31 of Set 13 | atambua
# Processing Record 32 of Set 13 | sao filipe
# Processing Record 33 of Set 13 | conakry
# Processing Record 34 of Set 13 | tazovskiy
# Processing Record 35 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 13 | palana
# Processing Record 37 of Set 13 | qom
# Processing Record 38 of Set 13 | luena
# Processing Record 39 of Set 13 | noumea
# Processing Record 40 of Set 13 | namatanai
# Processing Record 41 of Set 13 | umm lajj
# Processing Record 42 of Set 13 | opuwo
# Processing Record 43 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 44 of Set 13 | findlay
# Processing Record 45 of Set 13 | cedar rapids
# Processing Record 46 of Set 13 | lubango
# Processing Record 47 of Set 13 | goderich
# Processing Record 48 of Set 13 | itupiranga
# Processing Record 49 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 13 | bowen
# Processing Record 1 of Set 14 | altay
# Processing Record 2 of Set 14 | saldanha
# Processing Record 3 of Set 14 | sydney
# Processing Record 4 of Set 14 | khobi
# Processing Record 5 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 14 | labuhan
# Processing Record 7 of Set 14 | kitami
# Processing Record 8 of Set 14 | lavara
# Processing Record 9 of Set 14 | oyama
# Processing Record 10 of Set 14 | vasilsursk
# Processing Record 11 of Set 14 | hambantota
# Processing Record 12 of Set 14 | midland
# Processing Record 13 of Set 14 | hede
# Processing Record 14 of Set 14 | ponta do sol
# Processing Record 15 of Set 14 | carutapera
# Processing Record 16 of Set 14 | axim
# Processing Record 17 of Set 14 | pocatello
# Processing Record 18 of Set 14 | muroto
# Processing Record 19 of Set 14 | trofors
# Processing Record 20 of Set 14 | kashi
# Processing Record 21 of Set 14 | vardo
# Processing Record 22 of Set 14 | eureka
# Processing Record 23 of Set 14 | tiznit
# Processing Record 24 of Set 14 | luchegorsk
# Processing Record 25 of Set 14 | yanam
# Processing Record 26 of Set 14 | janakpur
# Processing Record 27 of Set 14 | ust-kut
# Processing Record 28 of Set 14 | qaqortoq
# Processing Record 29 of Set 14 | shitanjing
# Processing Record 30 of Set 14 | soyo
# Processing Record 31 of Set 14 | bangassou
# Processing Record 32 of Set 14 | san matias
# Processing Record 33 of Set 14 | tautira
# Processing Record 34 of Set 14 | palmital
# Processing Record 35 of Set 14 | san blas
# Processing Record 36 of Set 14 | luanda
# Processing Record 37 of Set 14 | antalaha
# Processing Record 38 of Set 14 | parrita
# Processing Record 39 of Set 14 | baijiantan
# Processing Record 40 of Set 14 | nazca
# Processing Record 41 of Set 14 | arrifes
# Processing Record 42 of Set 14 | nenjiang
# Processing Record 43 of Set 14 | pincher creek
# Processing Record 44 of Set 14 | socorro
# Processing Record 45 of Set 14 | miami
# Processing Record 46 of Set 14 | coquimbo
# Processing Record 47 of Set 14 | menongue
# Processing Record 48 of Set 14 | pochutla
# Processing Record 49 of Set 14 | platteville
# Processing Record 50 of Set 14 | whitehorse
# Processing Record 1 of Set 15 | edeia
# Processing Record 2 of Set 15 | chakia
# Processing Record 3 of Set 15 | la plata
# Processing Record 4 of Set 15 | bud
# Processing Record 5 of Set 15 | tahe
# Processing Record 6 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 7 of Set 15 | nome
# Processing Record 8 of Set 15 | anloga
# Processing Record 9 of Set 15 | kamenka
# Processing Record 10 of Set 15 | waipawa
# Processing Record 11 of Set 15 | sabaudia
# Processing Record 12 of Set 15 | san andres
# Processing Record 13 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 15 | amudalavalasa
# Processing Record 15 of Set 15 | phrai bung
# City not found. Skipping...
# Processing Record 16 of Set 15 | the valley
# Processing Record 17 of Set 15 | saint-joseph
# Processing Record 18 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 19 of Set 15 | semporna
# Processing Record 20 of Set 15 | nauta
# Processing Record 21 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 15 | kamarion
# Processing Record 23 of Set 15 | mishkino
# Processing Record 24 of Set 15 | novyy urgal
# Processing Record 25 of Set 15 | onega
# Processing Record 26 of Set 15 | komatipoort
# Processing Record 27 of Set 15 | himora
# City not found. Skipping...
# Processing Record 28 of Set 15 | tigil
# Processing Record 29 of Set 15 | asyut
# Processing Record 30 of Set 15 | yilan
# Processing Record 31 of Set 15 | samarinda
# Processing Record 32 of Set 15 | umm kaddadah
# Processing Record 33 of Set 15 | chaman
# Processing Record 34 of Set 15 | coihaique
# Processing Record 35 of Set 15 | berlevag
# Processing Record 36 of Set 15 | houma
# Processing Record 37 of Set 15 | marivan
# Processing Record 38 of Set 15 | freetown
# Processing Record 39 of Set 15 | oranzherei
# Processing Record 40 of Set 15 | toyooka
# Processing Record 41 of Set 15 | vikhorevka
# Processing Record 42 of Set 15 | caravelas
# Processing Record 43 of Set 15 | muros
# Processing Record 44 of Set 15 | jasper
# Processing Record 45 of Set 15 | illela
# Processing Record 46 of Set 15 | arroyo
# Processing Record 47 of Set 15 | sidi ali
# Processing Record 48 of Set 15 | atherton
# Processing Record 49 of Set 15 | huarmey
# Processing Record 50 of Set 15 | concepcion
# Processing Record 1 of Set 16 | gushikawa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#check legnth of city data
len(city_data)
# Out:
# 689

# %%
#convert to a pandas DataFrame, check for correct column order
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mar Del Plata      AR -38.0023  -57.5575     77.02        67           0
# 1      Saskylakh      RU  71.9167  114.0833    -19.82       100         100
# 2        Ushuaia      AR -54.8000  -68.3000     44.26        87         100
# 3    Provideniya      RU  64.3833 -173.3000      4.86        86          24
# 4       Marshall      US  34.3834  -86.3333     31.48        51           0
# 5     San Miguel      SV  13.4833  -88.1833     80.73        49          51
# 6      Busselton      AU -33.6500  115.3333     77.04        60           7
# 7       Sisimiut      GL  66.9395  -53.6735      6.85        83         100
# 8        Mataura      NZ -46.1927  168.8643     56.73        99         100
# 9          Kapaa      US  22.0752 -159.3190     80.58        66           0
#
#    Wind Speed Current Description
# 0       21.00           clear sky
# 1        3.78     overcast clouds
# 2        4.61          light rain
# 3        4.00          few clouds
# 4        1.14           clear sky
# 5        3.67       broken clouds
# 6       13.00           clear sky
# 7       28.83          light snow
# 8        2.64          light rain
# 9        1.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
